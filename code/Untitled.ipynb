# %%
import subprocess
import os

# %%
p = subprocess.Popen([pdf_path],shell=True)

# %%
pdf_path = os.path.abspath(os.getcwd() + "/../") + '\Resume-Max.pdf'

# %%
pdf_path
# Out:
# 'C:\\Users\\JamesDuong\\Desktop\\resume\\resume_email_automation\\Resume-Max.pdf'

# %%
p.kill()
